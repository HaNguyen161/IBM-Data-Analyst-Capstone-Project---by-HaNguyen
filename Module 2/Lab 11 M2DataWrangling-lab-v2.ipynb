# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# In this lab, you will perform data wrangling tasks to prepare raw data for analysis. Data wrangling involves cleaning, transforming, and organizing data into a structured format suitable for analysis. This lab focuses on tasks like identifying inconsistencies, encoding categorical variables, and feature transformation.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# - Identify and remove inconsistent data entries.
#
# - Encode categorical variables for analysis.
#
# - Handle missing values using multiple imputation strategies.
#
# - Apply feature scaling and transformation techniques.

# %% [markdown]
# #### Intsall the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 133.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 210.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 153.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 151.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 103.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 151.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Tasks

# %% [markdown]
# #### Step 1: Import the necessary module.

# %% [markdown]
# ### 1. Load the Dataset

# %% [markdown]
# <h5>1.1 Import necessary libraries and load the dataset.</h5>

# %% [markdown]
# Ensure the dataset is loaded correctly by displaying the first few rows.

# %%
# Import necessary libraries
import pandas as pd

# Load the Stack Overflow survey data
dataset_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"
df = pd.read_csv(dataset_url)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# #### 2. Explore the Dataset

# %% [markdown]
# <h5>2.1 Summarize the dataset by displaying the column data types, counts, and missing values.</h5>

# %%
# Write your code here
import pandas as pd

# Assuming your dataset is loaded into a DataFrame called 'df'
# df = pd.read_csv('your_dataset.csv')

# 1. Display column data types and non-null counts
print("Dataset Info (Data Types and Non-Null Counts):")
df.info()

# 2. Display exact count of missing values per column
print("\nMissing Values per Column:")
print(df.isnull().sum())
# Out:
# Dataset Info (Data Types and Non-Null Counts):
# <class 'pandas.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), str(100)
# memory usage: 56.9 MB
#
# Missing Values per Column:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork             10631
#                        ...
# JobSatPoints_11        35992
# SurveyLength            9255
# SurveyEase              9199
# ConvertedCompYearly    42002
# JobSat                 36311
# Length: 114, dtype: int64

# %% [markdown]
# <h5>2.2 Generate basic statistics for numerical columns.</h5>

# %%
# Write your code here
# Generate basic statistics (count, mean, std, min, 25%, 50%, 75%, max) for numerical columns
print(df.describe())
# Out:
#          ResponseId      CompTotal       WorkExp  JobSatPoints_1  \
# count  65437.000000   3.374000e+04  29658.000000    29324.000000
# mean   32719.000000  2.963841e+145     11.466957       18.581094
# std    18890.179119  5.444117e+147      9.168709       25.966221
# min        1.000000   0.000000e+00      0.000000        0.000000
# 25%    16360.000000   6.000000e+04      4.000000        0.000000
# 50%    32719.000000   1.100000e+05      9.000000       10.000000
# 75%    49078.000000   2.500000e+05     16.000000       22.000000
# max    65437.000000  1.000000e+150     50.000000      100.000000
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# count    29393.000000    29411.000000    29450.000000     29448.00000
# mean         7.522140       10.060857       24.343232        22.96522
# std         18.422661       21.833836       27.089360        27.01774
# min          0.000000        0.000000        0.000000         0.00000
# ...

# %% [markdown]
# ### 3. Identifying and Removing Inconsistencies

# %% [markdown]
# <h5>3.1 Identify inconsistent or irrelevant entries in specific columns (e.g., Country).</h5>

# %%
# Write your code here
# 1. View all unique entries in the 'Country' column
print("Unique entries in Country:")
print(df['Country'].unique())

# 2. View the count of each unique entry
print("\nFrequency of each entry:")
print(df['Country'].value_counts(dropna=False))
# Out:
# Unique entries in Country:
# <StringArray>
# [                            'United States of America',
#  'United Kingdom of Great Britain and Northern Ireland',
#                                                'Canada',
#                                                'Norway',
#                                            'Uzbekistan',
#                                                'Serbia',
#                                                'Poland',
#                                           'Philippines',
#                                              'Bulgaria',
#                                           'Switzerland',
#  ...
#                                 'Saint Kitts and Nevis',
#                                                'Monaco',
#                    'Micronesia, Federated States of...',
#                                                 'Haiti',
#                                                     nan,
#                                                 'Nauru',
# ...

# %% [markdown]
# <h5>3.2 Standardize entries in columns like Country or EdLevel by mapping inconsistent values to a consistent format.</h5>

# %%
## Write your code here
# 1. Standardizing the 'Country' column
country_mapping = {
    'USA': 'United States',
    'U.S.A.': 'United States',
    'US': 'United States',
    'UK': 'United Kingdom',
    'U.K.': 'United Kingdom'
}
# Replace the inconsistent values using the mapping dictionary
df['Country'] = df['Country'].replace(country_mapping)

# 2. Standardizing the 'EdLevel' column
edlevel_mapping = {
    'B.S.': "Bachelor's Degree",
    'Bachelors': "Bachelor's Degree",
    'Undergrad': "Bachelor's Degree",
    'M.S.': "Master's Degree",
    'Masters': "Master's Degree"
}
# Replace the inconsistent values using the mapping dictionary
df['EdLevel'] = df['EdLevel'].replace(edlevel_mapping)

# Verify the changes
print(df['Country'].unique())
print(df['EdLevel'].unique())
# Out:
# <StringArray>
# [                            'United States of America',
#  'United Kingdom of Great Britain and Northern Ireland',
#                                                'Canada',
#                                                'Norway',
#                                            'Uzbekistan',
#                                                'Serbia',
#                                                'Poland',
#                                           'Philippines',
#                                              'Bulgaria',
#                                           'Switzerland',
#  ...
#                                 'Saint Kitts and Nevis',
#                                                'Monaco',
#                    'Micronesia, Federated States of...',
#                                                 'Haiti',
#                                                     nan,
#                                                 'Nauru',
# ...

# %% [markdown]
# ### 4. Encoding Categorical Variables

# %% [markdown]
# <h5>4.1 Encode the Employment column using one-hot encoding.</h5>

# %%
## Write your code here
# Apply one-hot encoding to the 'Employment' column
df = pd.get_dummies(df, columns=['Employment'])

# Display the first few rows to verify the new columns
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age RemoteWork  \
# 0           1  I am a developer by profession  Under 18 years old     Remote
# 1           2  I am a developer by profession     35-44 years old     Remote
# 2           3  I am a developer by profession     45-54 years old     Remote
# 3           4           I am learning to code     18-24 years old        NaN
# 4           5  I am a developer by profession     18-24 years old        NaN
#
#     Check                                   CodingActivities  \
# 0  Apples                                              Hobby
# 1  Apples  Hobby;Contribute to open-source projects;Other...
# 2  Apples  Hobby;Contribute to open-source projects;Other...
# 3  Apples                                                NaN
# 4  Apples                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# ...

# %% [markdown]
# ### 5. Handling Missing Values

# %% [markdown]
# <h5>5.1 Identify columns with the highest number of missing values.</h5>

# %%
## Write your code here
# Calculate the sum of missing values per column and sort them from highest to lowest
missing_counts = df.isnull().sum().sort_values(ascending=False)

# Filter to show only columns that actually have missing values
columns_with_missing_data = missing_counts[missing_counts > 0]

print("Columns with the highest number of missing values:")
print(columns_with_missing_data)
# Out:
# Columns with the highest number of missing values:
# AINextMuch less integrated    64289
# AINextLess integrated         63082
# AINextNo change               52939
# AINextMuch more integrated    51999
# EmbeddedAdmired               48704
#                               ...
# YearsCode                      5568
# NEWSOSites                     5151
# LearnCode                      4949
# EdLevel                        4653
# AISelect                       4530
# Length: 109, dtype: int64

# %% [markdown]
# <h5>5.2 Impute missing values in numerical columns (e.g., `ConvertedCompYearly`) with the mean or median.</h5>

# %%
## Write your code here
# Option 1: Impute missing values with the mean
mean_value = df['ConvertedCompYearly'].mean()
df['ConvertedCompYearly'] = df['ConvertedCompYearly'].fillna(mean_value)

# Option 2: Impute missing values with the median (often preferred if data has outliers)
# median_value = df['ConvertedCompYearly'].median()
# df['ConvertedCompYearly'] = df['ConvertedCompYearly'].fillna(median_value)

# Verify the missing values have been filled
print("Remaining missing values:", df['ConvertedCompYearly'].isnull().sum())
# Out:
# Remaining missing values: 0

# %% [markdown]
# <h5>5.3 Impute missing values in categorical columns (e.g., `RemoteWork`) with the most frequent value.</h5>

# %%
## Write your code here
# 1. Find the most frequent value (the mode) in the 'RemoteWork' column
# mode() returns a Series, so we use  to extract the actual string value
most_frequent_value = df['RemoteWork'].mode()

# 2. Impute the missing values with this most frequent value
df['RemoteWork'] = df['RemoteWork'].fillna(most_frequent_value)

# 3. Verify that the missing values have been filled
print("Remaining missing values:", df['RemoteWork'].isnull().sum())
# Out:
# Remaining missing values: 10631

# %% [markdown]
# ### 6. Feature Scaling and Transformation

# %% [markdown]
# <h5>6.1 Apply Min-Max Scaling to normalize the `ConvertedCompYearly` column.</h5>

# %%
## Write your code here
# !pip install scikit-learn

from sklearn.preprocessing import MinMaxScaler

# 1. Initialize the MinMaxScaler
scaler = MinMaxScaler()

# 2. Apply the scaler to the column
# Note: We use double brackets [['...']] because the scaler expects a 2D DataFrame/array
df['ConvertedCompYearly_Normalized'] = scaler.fit_transform(df[['ConvertedCompYearly']])

# 3. Verify the changes by viewing the original and normalized columns
print(df[['ConvertedCompYearly', 'ConvertedCompYearly_Normalized']].head())
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 162.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 205.1 MB/s eta 0:00:00
# ...
#    ConvertedCompYearly  ConvertedCompYearly_Normalized
# 0         86155.287263                          0.0053
# 1         86155.287263                          0.0053
# 2         86155.287263                          0.0053
# 3         86155.287263                          0.0053
# 4         86155.287263                          0.0053

# %% [markdown]
# <h5>6.2 Log-transform the ConvertedCompYearly column to reduce skewness.</h5>

# %%
## Write your code here
import numpy as np

# Apply a log transformation to reduce right-skewness
# We use np.log1p() which calculates log(1 + x) to safely handle any zero values
df['ConvertedCompYearly_Log'] = np.log1p(df['ConvertedCompYearly'])

# Verify the transformation by viewing the original and transformed columns
print(df[['ConvertedCompYearly', 'ConvertedCompYearly_Log']].head())
# Out:
#    ConvertedCompYearly  ConvertedCompYearly_Log
# 0         86155.287263                11.363918
# 1         86155.287263                11.363918
# 2         86155.287263                11.363918
# 3         86155.287263                11.363918
# 4         86155.287263                11.363918

# %% [markdown]
# ### 7. Feature Engineering

# %% [markdown]
# <h5>7.1 Create a new column `ExperienceLevel` based on the `YearsCodePro` column:</h5>

# %%
# Create ExperienceLevel column based on YearsCodePro
def categorize_experience(years):
    try:
        years = float(years)

        if years < 3:
            return "Beginner"
        elif years < 7:
            return "Intermediate"
        else:
            return "Expert"

    except:
        return "Unknown"

df["ExperienceLevel"] = df["YearsCodePro"].apply(categorize_experience)

# Preview
print(df[["YearsCodePro", "ExperienceLevel"]].head())
# Out:
#    YearsCodePro ExperienceLevel
# 0           7.0          Expert
# 1          17.0          Expert
# 2          27.0          Expert
# 3           7.0          Expert
# 4           7.0          Expert

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you:
#
# - Explored the dataset to identify inconsistencies and missing values.
#
# - Encoded categorical variables for analysis.
#
# - Handled missing values using imputation techniques.
#
# - Normalized and transformed numerical data to prepare it for analysis.
#
# - Engineered a new feature to enhance data interpretation.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
